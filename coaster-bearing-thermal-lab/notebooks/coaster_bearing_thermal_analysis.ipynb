# %% [markdown]
# # Coaster Bearing Thermal Analysis\n\nこのNotebookは、READMEとsrc/main.pyをもとに後で解析ストーリーを整理するためのプレースホルダーです。\n\nThis notebook is a placeholder for the future analysis story based on README and src/main.py.
